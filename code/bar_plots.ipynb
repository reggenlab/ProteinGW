# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams['axes.xmargin'] = 0

# %%
Solubility = pd.DataFrame([['Random Forest',0.79,0.78,0.79,0.57],
['SVM',0.59,0.56,0.58,0.17],
['Logistic Regression',0.67,0.67,0.68,0.35],
['Gaussian Naïve Bayes',0.63,0.61,0.63,0.28],
['KNN',0.574,0.57,0.625,0.2417],
['AdaBoost',0.611,0.61,0.611,0.22],
['XgBoost',0.66,0.66,0.66,0.33]])

Solubility.columns = ['','Accuracy','Macro-F1','ROC AUC','MCC']
Solubility.index =  Solubility.iloc[:,0]
Solubility = Solubility.iloc[:,1:]
# Solubility = Solubility.iloc[1:,:]

error_bar = [[0.06,0.05,0.05,0.11],
            [0.05,0.05,0.05,0.11],
            [0.11,0.11,0.11,0.20],
            [0.09,0.12,0.09,0.17],
             [0.11,0.13,0.13,0.16],
             [0.12,0.13,0.13,0.16],
             [0.12,0.12,0.12,0.15]
            ]

error_bar = pd.DataFrame(error_bar)
error_bar.columns = Solubility.columns
error_bar.index = Solubility.index

# %%
import pandas as pd
import matplotlib.pyplot as plt
# plt.style.use('ggplot')
ax = Solubility.T.plot.bar(yerr=error_bar.T, alpha = 1,error_kw=dict(ecolor='k'),edgecolor='white',width=0.9,fontsize=12, capsize=2, rot=0,colormap="Set2",figsize=(6,4))
# for container in ax.containers:
#     plt.setp(container, width=1)      

legend_properties = {'weight':'bold','size':12}

ax.set_ylim(0.0, 1)
plt.title("Solubility (Classification)",fontsize=12,fontweight="bold")
plt.tight_layout()
plt.setp(ax.get_yticklabels(), fontweight="bold")
plt.setp(ax.get_xticklabels(), fontweight="bold")
plt.legend(bbox_to_anchor=(1.05, 1),prop=legend_properties)
plt.show()

# %%
Solubility = pd.DataFrame([['Random Forest',0.93,0.88,0.86,0.77],
['SVM',0.91,0.85,0.83,0.70],
['Logistic Regression',0.90,0.81,0.81,0.63],
['Gaussian Naïve Bayes',0.80,0.71,0.75,0.45],
['KNN',0.91,0.81,0.78,0.63],
['AdaBoost',0.93,0.88,0.85,0.78],
['XgBoost',0.94,0.89,0.88,0.78]])

Solubility.columns = ['','Accuracy','Macro-F1','ROC AUC','MCC']
Solubility.index =  Solubility.iloc[:,0]
Solubility = Solubility.iloc[:,1:]
# Solubility = Solubility.iloc[1:,:]

error_bar = [[0.08,0.15,0.17,0.30],
            [0.08,0.14,0.12,0.28],
            [0.03,0.06,0.12,0.12],
            [0.10,0.15,0.14,0.27],
             [0.03,0.12,0.13,0.23],
             [0.04,0.08,0.11,0.16],
             [0.07,0.14,0.08,0.27]
            ]

error_bar = pd.DataFrame(np.array(error_bar))
error_bar.columns = Solubility.columns
error_bar.index = Solubility.index

# %%
import pandas as pd
import matplotlib.pyplot as plt

ax = Solubility.T.plot.bar(yerr=error_bar.T, alpha = 1,error_kw=dict(ecolor='k'),edgecolor='white',width=0.9,fontsize=12, capsize=2, rot=0,colormap="Set2",figsize=(6,4))
# for container in ax.containers:
#     plt.setp(container, width=1)      

legend_properties = {'weight':'bold','size':12}

# ax.axes.set_xlim(0.0, 0)
plt.title("Transmembrane-Globular (Classification)",fontsize=12,fontweight="bold")
plt.tight_layout()
plt.setp(ax.get_yticklabels(), fontweight="bold")
plt.setp(ax.get_xticklabels(), fontweight="bold")
plt.legend(bbox_to_anchor=(1.05, 1),prop=legend_properties)
plt.show()

# %%
Solubility = pd.DataFrame([['Random Forest',0.75,0.73,0.75,0.57],
['SVM',0.75,0.73,0.75,0.57],
['Logistic Regression',0.83,0.78,0.75,0.63],
['Gaussian Naïve Bayes',0.83,0.78,0.75,0.63],
['KNN',0.66,0.40,0.5,0.20],
['AdaBoost',0.83,0.78,0.75,0.63],
['XgBoost',0.83,0.78,0.75,0.63]])

Solubility.columns = ['','Accuracy','Macro-F1','ROC AUC','MCC']
Solubility.index =  Solubility.iloc[:,0]
Solubility = Solubility.iloc[:,1:]
# Solubility = Solubility.iloc[1:,:]

error_bar = [[0.01,0.01,0.01,0.04],
            [0.03,0.02,0.03,0.04],
            [0.03,0.06,0.02,0.05],
            [0.07,0.05,0.04,0.07],
             [0.03,0.02,0.03,0.03],
             [0.04,0.08,0.01,0.06],
             [0.07,0.04,0.08,0.07]
            ]

error_bar = pd.DataFrame(np.array(error_bar))
error_bar.columns = Solubility.columns
error_bar.index = Solubility.index

# %%
import pandas as pd
import matplotlib.pyplot as plt

ax = Solubility.T.plot.bar(yerr=error_bar.T, alpha = 1,error_kw=dict(ecolor='k'),edgecolor='white',width=0.9,fontsize=12, capsize=2, rot=0,colormap="Set2",figsize=(6,4))
# for container in ax.containers:
#     plt.setp(container, width=1)      

legend_properties = {'weight':'bold','size':12}

# ax.axes.set_xlim(0.0, 0)
plt.title("All-α, all-β (Classification)",fontsize=12,fontweight="bold")
plt.tight_layout()
plt.setp(ax.get_yticklabels(), fontweight="bold")
plt.setp(ax.get_xticklabels(), fontweight="bold")
plt.legend(bbox_to_anchor=(1.05, 1),prop=legend_properties)
plt.show()

# %%
Solubility = pd.DataFrame([['Random Forest',0.81],
['Linear Regression',0.45],
['Lasso',0.56],
['Ridge',0.53],
['SVR',0.68],
['K-Nearest Neighbor',0.43],
['Decision Tree',0.55],
['Elastic Net',0.75]])

Solubility.columns = ['','R-value']
Solubility.index =  Solubility.iloc[:,0]
Solubility = Solubility.iloc[:,1:]
# Solubility = Solubility.iloc[1:,:]

error_bar = [[0.12],
            [0.35],
            [0.17],
            [0.40],
             [0.16],
             [0.25],
             [0.30],
             [0.16]
            ]

error_bar = pd.DataFrame(np.array(error_bar))
error_bar.columns = Solubility.columns
error_bar.index = Solubility.index

# %%
import pandas as pd
import matplotlib.pyplot as plt

ax = Solubility.plot.bar(yerr=error_bar, alpha = 1,error_kw=dict(ecolor='k'),edgecolor='white',fontsize=12, capsize=2, rot=90,colormap="Set1",figsize=(7,5))
# for container in ax.containers:
#     plt.setp(container, width=1)      

legend_properties = {'weight':'bold','size':12}

# ax.axes.set_xlim(0.0, 0)
plt.title("Protein Folding Rate (Regression)",fontsize=12,fontweight="bold")
plt.ylabel("R (Protein Folding Rate)",fontsize=12,fontweight="bold")
plt.tight_layout()
plt.setp(ax.get_yticklabels(), fontweight="bold")
plt.setp(ax.get_xticklabels(), fontweight="bold")
plt.legend(bbox_to_anchor=(1.05, 1),prop=legend_properties)
plt.show()

# %%
rmse = pd.DataFrame([['Random Forest',np.sqrt(2.84)],
['Linear Regression',np.sqrt(3.81)],
['Lasso',np.sqrt(3.39)],
['Ridge',np.sqrt(3.37)],
['SVR',np.sqrt(3.38)],
['K-Nearest Neighbor',np.sqrt(3.48)],
['Decision Tree',np.sqrt(3.82)],
['Elastic Net',np.sqrt(2.78)]])

rmse.columns = ['','RMSE']
rmse.index =  rmse.iloc[:,0]
rmse = rmse.iloc[:,1:]
# Solubility = Solubility.iloc[1:,:]

error_bar = [[0.39],
            [1.40],
            [1.01],
            [0.93],
             [0.95],
             [1.11],
             [1.23],
             [1.02]
            ]

error_bar = pd.DataFrame(np.array(error_bar))
error_bar.columns = rmse.columns
error_bar.index = rmse.index

# %%
rmse
# Out:
#                         RMSE
#
# Random Forest       1.685230
# Linear Regression   1.951922
# Lasso               1.841195
# Ridge               1.835756
# SVR                 1.838478
# K-Nearest Neighbor  1.865476
# Decision Tree       1.954482
# Elastic Net         1.667333

# %%
import pandas as pd
import matplotlib.pyplot as plt

ax = rmse.plot.bar(yerr=error_bar, alpha = 1,error_kw=dict(ecolor='k'),edgecolor='white',fontsize=12, capsize=3, rot=90,colormap="Set3",figsize=(7,4))
# for container in ax.containers:
#     plt.setp(container, width=1)      

legend_properties = {'weight':'bold','size':12}
ax.margins(x=0.01)

# ax.axes.set_xlim(0.0, 0)
plt.title("Protein Folding Rate (RMSE)",fontsize=12,fontweight="bold")
plt.ylabel("RMSE (Protein Folding Rate)",fontsize=12,fontweight="bold")
# plt.tight_layout()
plt.setp(ax.get_yticklabels(), fontweight="bold")
plt.setp(ax.get_xticklabels(), fontweight="bold")
plt.legend(bbox_to_anchor=(1.05, 1),prop=legend_properties)
plt.show()

# %%
ax.margins
# Out:
# <bound method _AxesBase.margins of <matplotlib.axes._subplots.AxesSubplot object at 0x7f9cb2e880f0>>

# %%
x = [['ind','PFR before Mutation','PFR after Mutation'],
['1V9E,His94Tyr,Osteopetrosis, autosomal recessive 3',-4.4,7.71],
['2A5E,Met53Ile, Melanoma, cutaneous malignant 2',3.5,7.60809],
['2A5E, Val95Ala , Non-small cell lung carcinoma',3.5,7.60527],
['2A5E,Glu119Gln, A biliary tract tumor',3.5,7.60739]]

# %%
x = pd.DataFrame(x)
x.columns= x.loc[0,:]
x = x.loc[1:,:]

# %%
x['diff'] = x['PFR after Mutation'] - x['PFR before Mutation']

# %%
x
# Out:
# 0                                                ind PFR before Mutation  \
# 1  1V9E,His94Tyr,Osteopetrosis, autosomal recessi...                -4.4
# 2     2A5E,Met53Ile, Melanoma, cutaneous malignant 2                 3.5
# 3     2A5E, Val95Ala , Non-small cell lung carcinoma                 3.5
# 4              2A5E,Glu119Gln, A biliary tract tumor                 3.5
#
# 0 PFR after Mutation     diff
# 1               7.71    12.11
# 2            7.60809  4.10809
# 3            7.60527  4.10527
# 4            7.60739  4.10739

# %%
x.index = x['ind']

# %%
import pandas as pd
import matplotlib.pyplot as plt

ax = x['diff'].T.plot.bar(alpha = 1,error_kw=dict(ecolor='k'),edgecolor='white',fontsize=12, capsize=3, rot=90,color = 'orangered',figsize=(5,4),orientation='vertical')
# for container in ax.containers:
#     plt.setp(container, width=1)      

legend_properties = {'weight':'bold','size':12}
ax.margins(x=0.01)
ax.invert_xaxis()

# ax.axes.set_xlim(0.0, 0)
# plt.title("Change in Protein Folding Rate",fontsize=12,fontweight="bold")
plt.ylabel("Change in Protein folding rate",fontsize=12,fontweight="bold")
# plt.tight_layout(),
plt.setp(ax.get_yticklabels(), fontweight="bold", rotation=90)
# plt.xticks(x['ind'])
plt.setp(ax.get_xticklabels(), fontweight="bold")
# plt.legend(bbox_to_anchor=(1.05, 1),prop=legend_properties)
plt.show()

# %%
x
# Out:
# 0                                                ind PFR before Mutation  \
# 1  1V9E,Mutation : His94Tyr,Osteopetrosis, autoso...                -4.4
# 2     2A5E,Met53Ile, Melanoma, cutaneous malignant 2                 3.5
# 3     2A5E, Val95Ala , Non-small cell lung carcinoma                 3.5
# 4              2A5E,Glu119Gln, A biliary tract tumor                 3.5
#
# 0 PFR after Mutation     diff
# 1               7.71    12.11
# 2            7.60809  4.10809
# 3            7.60527  4.10527
# 4            7.60739  4.10739
