# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
peaks = [0.85,0.8,0.75,0.66,0.5,0.33]
s1 = [0.67,0.66,0.61,0.55,0.53,0.51]
s2 = [0.80,0.80,0.80,0.79,0.78,0.67]
s3 = [0.66,0.73,0.65,0.59,0.6,0.54]
plt.plot(peaks, s1, color='red', marker='o',linewidth=3.0, label='GFT')
plt.plot(peaks, s2, color='olive', marker='o',linewidth=3.0,label='Graph-Wavelet')
plt.plot(peaks, s3, color='blue', marker='o',linewidth=3.0,label='CNN')
plt.ylim(ymin=0)
plt.legend(frameon=False)
plt.xlabel('Fraction of Training Data',size=20)
plt.ylabel('Accuracy of Model',size=20)
plt.title('Accuracy-Alpha/Beta Classification',size=15)
# plt.savefig("nearest_gene.png")
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# Text(0.5, 1.0, 'Accuracy-Alpha/Beta Classification')

# %%
import matplotlib.pyplot as plt
peaks = [0.85,0.8,0.75,0.66,0.5,0.33]
s1 = [0.56,0.60,0.57,0.60,0.52,0.49]
s2 = [0.77,0.77,0.76,0.76,0.76,0.53]
s3 = [0.67,0.70,0.68,0.69,0.63,0.54]
plt.plot(peaks, s1, color='red', marker='o',linewidth=3.0, label='GFT')
plt.plot(peaks, s2, color='olive', marker='o',linewidth=3.0,label='Graph-Wavelet')
plt.plot(peaks, s3, color='blue', marker='o',linewidth=3.0,label='CNN')
plt.ylim(ymin=0)
plt.legend(frameon=False)
plt.xlabel('Fraction of Training Data',size=20)
plt.ylabel('F1 Score',size=20)
plt.title('F1 Score-Alpha/Beta Classification',size=15)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# Text(0.5, 1.0, 'F1 Score-Alpha/Beta Classification')

# %%
import matplotlib.pyplot as plt
peaks = [0.85,0.8,0.75,0.66,0.5,0.33]
s1 = [0.59,0.60,0.58,0.61,0.68,0.62]
s2 = [0.75,0.75,0.75,0.75,0.70,0.50]
s3 = [0.60,0.57,0.66,0.67,0.69,0.68]
plt.plot(peaks, s1, color='red', marker='o',linewidth=3.0, label='GFT')
plt.plot(peaks, s2, color='olive', marker='o',linewidth=3.0,label='Graph-Wavelet')
plt.plot(peaks, s3, color='blue', marker='o',linewidth=3.0,label='CNN')
plt.ylim(ymin=0)
plt.legend(frameon=False)
plt.xlabel('Fraction of Training Data',size=20)
plt.ylabel('AUCROC',size=20)
plt.title('AUCROC-Alpha/Beta Classification',size=15)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# Text(0.5, 1.0, 'AUCROC-Alpha/Beta Classification')

# %%
import matplotlib.pyplot as plt
peaks = [0.85,0.8,0.75,0.66,0.5,0.33,0.25,0.20]
s1 = [0.83,0.77,0.78,0.77,0.74,0.78,0.78,0.77]
s2 = [0.85,0.82,0.82,0.8,0.82,0.78,0.76,0.75]
s3 = [0.91,0.92,0.92,0.92,0.92,0.92,0.88,0.86]
plt.plot(peaks, s1, color='red', marker='o',linewidth=3.0, label='GFT')
plt.plot(peaks, s2, color='blue', marker='o',linewidth=3.0,label='CNN')
plt.plot(peaks, s3, color='olive', marker='o',linewidth=3.0,label='Graph-Wavelet')
plt.ylim(ymin=0,ymax=1)
plt.legend(frameon=False)
plt.xlabel('Fraction of Training Data',size=20)
plt.ylabel('Accuracy of Model',size=20)
plt.title('Accuracy-Transmembrane/Globular Classification',size=15)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# Text(0.5, 1.0, 'Accuracy-Transmembrane/Globular Classification')

# %%
import matplotlib.pyplot as plt
peaks = [0.85,0.8,0.75,0.66,0.5,0.33,0.25,0.20]
s1 = [0.65,0.67,0.63,0.64,0.59,0.59,0.52,0.55]
s2 = [0.71,0.70,0.68,0.68,0.65,0.65,0.63,0.61]
s3 = [0.87,0.90,0.87,0.87,0.87,0.86,0.78,0.69]
plt.plot(peaks, s1, color='red', marker='o',linewidth=3.0, label='GFT')
plt.plot(peaks, s2, color='blue', marker='o',linewidth=3.0,label='CNN')
plt.plot(peaks, s3, color='olive', marker='o',linewidth=3.0,label='Graph-Wavelet')
plt.ylim(ymin=0)
plt.legend(frameon=False)
plt.xlabel('Fraction of Training Data',size=20)
plt.ylabel('F1 Score',size=20)
plt.title('F1 Score-Transmembrane/Globular Classification',size=15)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# Text(0.5, 1.0, 'F1 Score-Transmembrane/Globular Classification')

# %%
import matplotlib.pyplot as plt
peaks = [0.85,0.8,0.75,0.66,0.5,0.33,0.25,0.20]
s1 = [0.67,0.65,0.58,0.63,0.65,0.57,0.54,0.54]
s2 = [0.69,0.72,0.67,0.68,0.66,0.67,0.67,0.67]
s3 = [0.886,0.9130,0.823,0.8541,0.8084,0.8035,0.7217,0.6841]
plt.plot(peaks, s1, color='red', marker='o',linewidth=3.0, label='GFT')
plt.plot(peaks, s2, color='blue', marker='o',linewidth=3.0,label='CNN')
plt.plot(peaks, s3, color='olive', marker='o',linewidth=3.0,label='Graph-Wavelet')
plt.ylim(ymin=0)
plt.legend(frameon=False)
plt.xlabel('Fraction of Training Data',size=20)
plt.ylabel('AUCROC',size=20)
plt.title('AUCROC-Transmembrane/Globular Classification',size=15)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# Text(0.5, 1.0, 'AUCROC-Transmembrane/Globular Classification')

# %%
import matplotlib.pyplot as plt
peaks = [0.85,0.8,0.75,0.66,0.5,0.33,0.25,0.20]
s1 = [0.60,0.61,0.59,0.60,0.57,0.59,0.61,0.57]
s2 = [0.58,0.60,0.60,0.58,0.59,0.58,0.59,0.57]
s3 = [0.76,0.69,0.69,0.67,0.66,0.65,0.65,0.64]
plt.plot(peaks, s1, color='red', marker='o',linewidth=3.0, label='GFT')
plt.plot(peaks, s2, color='blue', marker='o',linewidth=3.0,label='CNN')
plt.plot(peaks, s3, color='olive', marker='o',linewidth=3.0,label='Graph-Wavelet')
plt.ylim(ymin=0,ymax=1)
plt.legend(frameon=False)
plt.xlabel('Fraction of Training Data',size=20)
plt.ylabel('Accuracy of Model',size=20)
plt.title('Accuracy-Solubility Classification',size=15)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# Text(0.5, 1.0, 'Accuracy-Solubility Classification')

# %%
import matplotlib.pyplot as plt
peaks = [0.85,0.8,0.75,0.66,0.5,0.33,0.25,0.20]
s1 = [0.57,0.60,0.58,0.61,0.58,0.55,0.57,0.52]
s2 = [0.58,0.59,0.60,0.58,0.60,0.59,0.59,0.57]
s3 = [0.75,0.68,0.69,0.67,0.66,0.65,0.65,0.64]
plt.plot(peaks, s1, color='red', marker='o',linewidth=3.0, label='GFT')
plt.plot(peaks, s2, color='blue', marker='o',linewidth=3.0,label='CNN')
plt.plot(peaks, s3, color='olive', marker='o',linewidth=3.0,label='Graph-Wavelet')
plt.ylim(ymin=0,ymax=1)
plt.legend(frameon=False)
plt.xlabel('Fraction of Training Data',size=20)
plt.ylabel('Accuracy of Model',size=20)
plt.title('F1 Score-Solubility Classification',size=15)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# Text(0.5, 1.0, 'F1 Score-Solubility Classification')

# %%
import matplotlib.pyplot as plt
peaks = [0.85,0.8,0.75,0.66,0.5,0.33,0.25,0.20]
s1 = [0.63,0.61,0.59,0.60,0.61,0.59,0.61,0.58]
s2 = [0.58,0.59,0.61,0.58,0.60,0.58,0.57,0.58]
s3 = [0.7463768,0.6851,0.6879,0.67,0.66,0.65,0.64,0.64]
plt.plot(peaks, s1, color='red', marker='o',linewidth=3.0, label='GFT')
plt.plot(peaks, s2, color='blue', marker='o',linewidth=3.0,label='CNN')
plt.plot(peaks, s3, color='olive', marker='o',linewidth=3.0,label='Graph-Wavelet')
plt.ylim(ymin=0,ymax=1)
plt.legend(frameon=False)
plt.xlabel('Fraction of Training Data',size=20)
plt.ylabel('Accuracy of Model',size=20)
plt.title('AUROC-Solubility Classification',size=15)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3604: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# Text(0.5, 1.0, 'AUROC-Solubility Classification')
